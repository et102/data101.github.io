# %% [markdown]
# ## Is Fandango Still Inflating movie ratings?
# ### Background:
# Walt Hickey published an article where he showed evidence that Fandango's rating system was biased. In this project, we will investigae if Fandango has made any changes after Hickey's publication.
# ### Goal:
# We will work with two samples of movie rating to get familiar with ETL skills: sampling, variables, scales of measurement, and frequency distributions.
# #### Eric Tsai (yytsai1002@gmail.com)
# #### Oct 2018

# %% [markdown]
# ### Data redin-in and preview

# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
from numpy import arange
# %matplotlib inline

before = pd.read_csv('../data/fandango_score_comparison.csv')
after = pd.read_csv('../data/movie_ratings_16_17.csv')

# %%
before.info()
before.describe()
before.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 22 columns):
# FILM                          146 non-null object
# RottenTomatoes                146 non-null int64
# RottenTomatoes_User           146 non-null int64
# Metacritic                    146 non-null int64
# Metacritic_User               146 non-null float64
# IMDB                          146 non-null float64
# Fandango_Stars                146 non-null float64
# Fandango_Ratingvalue          146 non-null float64
# RT_norm                       146 non-null float64
# RT_user_norm                  146 non-null float64
# Metacritic_norm               146 non-null float64
# Metacritic_user_nom           146 non-null float64
# IMDB_norm                     146 non-null float64
# RT_norm_round                 146 non-null float64
# RT_user_norm_round            146 non-null float64
# Metacritic_norm_round         146 non-null float64
# ...

# %%
after.info()
after.describe()
after.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 15 columns):
# movie           214 non-null object
# year            214 non-null int64
# metascore       214 non-null int64
# imdb            214 non-null float64
# tmeter          214 non-null int64
# audience        214 non-null int64
# fandango        214 non-null float64
# n_metascore     214 non-null float64
# n_imdb          214 non-null float64
# n_tmeter        214 non-null float64
# n_audience      214 non-null float64
# nr_metascore    214 non-null float64
# nr_imdb         214 non-null float64
# nr_tmeter       214 non-null float64
# nr_audience     214 non-null float64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 25.2+ KB
#                      movie  year  metascore  imdb  tmeter  audience  fandango  \
# 0      10 Cloverfield Lane  2016         76   7.2      90        79       3.5
# 1                 13 Hours  2016         48   7.3      50        83       4.5
# ...

# %% [markdown]
# #### Pre-clean: selecting only important columns

# %%
fan_cols = ['FILM', 'Fandango_Stars', 'Fandango_Ratingvalue', 'Fandango_votes', 'Fandango_Difference']
before_revised = before[fan_cols].copy()

movie_rat_col = ['movie', 'year', 'fandango']
after_revised = after[movie_rat_col].copy()

## Note: use copy() because we don't want to change original dataframe object

# %%
before
# Out:
#                                                FILM  RottenTomatoes  \
# 0                    Avengers: Age of Ultron (2015)              74
# 1                                 Cinderella (2015)              85
# 2                                    Ant-Man (2015)              80
# 3                            Do You Believe? (2015)              18
# 4                     Hot Tub Time Machine 2 (2015)              14
# 5                          The Water Diviner (2015)              63
# 6                             Irrational Man (2015)              42
# 7                                   Top Five (2014)              86
# 8                      Shaun the Sheep Movie (2015)              99
# 9                               Love & Mercy (2015)              89
# 10                Far From The Madding Crowd (2015)              84
# 11                                 Black Sea (2015)              82
# 12                                 Leviathan (2014)              99
# ...

# %% [markdown]
# ### Examining quality of two samples
# #### Sampling criteria:
# 1. Sample 1:
#  The movie must have had at least 30 fan ratings on Fandango's website at the time of sampling (Aug. 24, 2015).
#  The movie must have had tickets on sale in 2015.
# 2. Sample 2:
# The movie must have been released in 2016 or later.
# The movie must have had a considerable number of votes and reviews (unclear how many from the README.md or from the data).
#
# #### Findings:
# By examing two datesets from author's github, I found that the they adopted **purposive sampling (or judgmental/selective/subjective sampling)**, which means both samples aren't representative enough to investigate changes before and after. However, it is possible to only see if any **"differences"** in two samples.
#
# #### Clean criteria:
# As we only need to find out the differences, below is cleaning criteria for datasets:
# 1. All Fandango's ratings for popular movies released in 2015.
# 2. All Fandango's ratings for popular movies released in 2016.

# %% [markdown]
# ### Check popularity

# %%
before_revised[before_revised["Fandango_votes"] < 30]
# Out:
# Empty DataFrame
# Columns: [FILM, Fandango_Stars, Fandango_Ratingvalue, Fandango_votes, Fandango_Difference]
# Index: []

# %% [markdown]
# #### Sample 2: After
# As the sample doesn't provide information about number of fan votes, we can only check pupularity in the website. To do this, we randomly sample 10 or 20 samples and check on Fandango's website

# %%
after_revised.sample(20, random_state = 1)
# Out:
#                                                 movie  year  fandango
# 108                            Mechanic: Resurrection  2016       4.0
# 206                                          Warcraft  2016       4.0
# 106                                         Max Steel  2016       3.5
# 107                                     Me Before You  2016       4.5
# 51            Fantastic Beasts and Where to Find Them  2016       4.5
# 33                                               Cell  2016       3.0
# 59                                             Genius  2016       3.5
# 152                                             Sully  2016       4.5
# 4                             A Hologram for the King  2016       3.0
# 31                         Captain America: Civil War  2016       4.5
# 118                                        Mr. Church  2016       4.5
# 39   Crouching Tiger, Hidden Dragon: Sword of Destiny  2016       4.0
# ...

# %% [markdown]
# ### Check year: 2015 & 2016

# %% [markdown]
# #### Sample 1:

# %%
## no column 'year', can only extract from column "FILM"

#print(before_revised["FILM"].head(3))

before_revised["year"] = before_revised['FILM'].str[-5:-1]
#before_revised["year"].value_counts()

before_revised_2015 = before_revised[before_revised["year"]== "2015"].copy()
before_revised_2015["year"].value_counts()
# Out:
# 2015    129
# Name: year, dtype: int64

# %% [markdown]
# #### Sample 2:

# %%
after_revised["year"].value_counts()

after_revised_2016 = after_revised[after_revised["year"] == 2016].copy()
after_revised_2016["year"].value_counts()
after_revised_2016
# Out:
#                                   movie  year  fandango
# 0                   10 Cloverfield Lane  2016       3.5
# 1                              13 Hours  2016       4.5
# 2                   A Cure for Wellness  2016       3.0
# 4               A Hologram for the King  2016       3.0
# 5                       A Monster Calls  2016       4.0
# 6                A Street Cat Named Bob  2016       4.5
# 7       Alice Through the Looking Glass  2016       4.0
# 8                                Allied  2016       4.0
# 9                         Amateur Night  2016       3.5
# 10                           Anthropoid  2016       4.0
# 11              Approaching the Unknown  2016       3.5
# 12                              Arrival  2016       4.0
# 14                     Assassin's Creed  2016       4.0
# 15                             Bad Moms  2016       4.5
# 16                          Bad Santa 2  2016       3.5
# 17             Barbershop: The Next Cut  2016       4.5
# ...

# %% [markdown]
# ### Comparing distribution shape

# %% [markdown]
# #### FiveThirtyEight (FTE) visualization for distribution plot

# %%
plt.style.use('fivethirtyeight')


before_revised_2015['Fandango_Stars'].plot.kde(label = '2015', legend = True, figsize = (8,5.5))

after_revised_2016['fandango'].plot.kde(label = '2016', legend = True,)

plt.title("Distribution comparison for Fandango ratings\n(2015 vs 2016)",
          y = 1.05) #  y parameter pads the title upward
plt.xlabel('Stars')

plt.xlim(0,5) # because ratings start at 0 and end at 5
plt.xticks(arange(0,5.1,.5))
plt.show()

# %% [markdown]
# #### Findings:
# 1. Both is strongly left skewed.
# 2. Distribution of 2016 is slightly left shifted, showing the rating is down after the article

# %% [markdown]
# #### Frequency distribution tables

# %%
print(before_revised_2015['Fandango_Stars'].value_counts(normalize = True).sort_index() * 100)
print(after_revised_2016['fandango'].value_counts(normalize = True).sort_index() * 100)
# Out:
# 3.0     8.527132
# 3.5    17.829457
# 4.0    28.682171
# 4.5    37.984496
# 5.0     6.976744
# Name: Fandango_Stars, dtype: float64
# 2.5     3.141361
# 3.0     7.329843
# 3.5    24.083770
# 4.0    40.314136
# 4.5    24.607330
# 5.0     0.523560
# Name: fandango, dtype: float64

# %% [markdown]
# #### Findings:
# 1. High ratings(4.5 & 5) are below 1% in 2016
# 2. Minimum rating (2.5) appears in 2016, which is 0 in 2015

# %% [markdown]
# ### Statistical analysis

# %%
mean_2015 = before_revised_2015['Fandango_Stars'].mean()
mean_2016 = after_revised_2016['fandango'].mean()

median_2015 = before_revised_2015['Fandango_Stars'].median()
median_2016 = after_revised_2016['fandango'].median()

mode_2015 = before_revised_2015['Fandango_Stars'].mode()[0]
mode_2016 = after_revised_2016['fandango'].mode()[0]

## creating panda data frame
sta_summary = pd.DataFrame()
sta_summary['2015'] = [mean_2015, median_2015, mode_2015]
sta_summary['2016'] = [mean_2016, median_2016, mode_2016]
sta_summary.index = ['mean', 'median', 'mode']
sta_summary
# Out:
#             2015      2016
# mean    4.085271  3.887435
# median  4.000000  4.000000
# mode    4.500000  4.000000

# %% [markdown]
# #### FiveThirtyEight (FTE) visualization for distribution statistical summary

# %%
plt.style.use('fivethirtyeight')

sta_summary['2015'].plot.bar(color = '#0066AF', align = 'center', label = '2015', width = .25,rot = 0, figsize = (8,5))
sta_summary['2016'].plot.bar(color = '#CC15B0', align = 'edge', label = '2016', width = .25)

plt.title('Summary statistics: 2015 vs 2016', y = 1.05)
plt.ylim(0,5.5)
plt.yticks(arange(0,5.5,.5))
plt.ylabel('Stars')
plt.legend(framealpha = 1, loc = 'upper center')
plt.show()

# %% [markdown]
# ### Conclusion
# The difference between 2015 and 2016 is confirmed but we are not sure what changes have been made by Fandango to lower the overall rating.
